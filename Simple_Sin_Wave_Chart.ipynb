# %% [markdown]
# <a href="https://colab.research.google.com/github/miksang0/Simple-Sin-Wave-Chart/blob/main/Simple_Sin_Wave_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x_values = np.arange(0, 10, 0.1)
y_values = np.sin(x_values)

plt.plot(x_values, y_values, label = 'Sin Chart')
plt.xlabel('X-axis')
plt.xlabel('Y-axis')
plt.title('Control Sin Chart')

plt.legend()

plt.show()
